# %%
import os
import pandas as pd
import numpy as np
import json
import re
import gensim
import nltk
import requests
import datetime
import seaborn as sns
import calplot

from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from gensim import corpora, models
from nltk.stem import WordNetLemmatizer
from bs4 import BeautifulSoup
from datetime import datetime
from datetime import timedelta
from dateutil.relativedelta import relativedelta
import matplotlib.pyplot as plt
import re
# Out:
# C:\tools\Anaconda3\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
pinoy_jobs = pd.read_json (r'pinoy_jobs.json')

# %%
#pinoy_jobs = pinoy_jobs.rename(columns = {'Years of Work Expirience': 'Years of Work Experience'}, inplace = False)

# %%
#pinoyjobs_df_json_clean = pd.read_json (r'pinoyjobs_df_json_clean.json')

# %%
#pinoyjobs_df_json_clean = pinoyjobs_df_json_clean.rename(columns = {'Years of Work Expirience': 'Years of Work Experience','Min Years of Work Expirience': 'Min Years of Work Experience','Max Years of Work Expirience': 'Max Years of Work Experience'}, inplace = False)

# %%
#workbank = pd.read_json (r'workbank.json')

# %%
#workbank = workbank.rename(columns = {'Years of Work Expirience': 'Years of Work Experience'}, inplace = False)

# %%
#workbank_df_json_clean = pd.read_json (r'workbank_df_json_clean.json')

# %%
#workbank_df_json_clean = workbank_df_json_clean.rename(columns = {'Years of Work Expirience': 'Years of Work Experience','Min Years of Work Expirience': 'Min Years of Work Experience','Max Years of Work Expirience': 'Max Years of Work Experience'}, inplace = False)

# %%
#compiled_df = pd.read_json (r'compiled_df.json')

# %%
#compiled_df = compiled_df.rename(columns = {'Years of Work Expirience': 'Years of Work Experience','Min Years of Work Expirience': 'Min Years of Work Experience','Max Years of Work Expirience': 'Max Years of Work Experience'}, inplace = False)

# %%
monster_ph_df_json_1 = pd.read_json(r'Monster Data/monster_ph_IT.json')
monster_ph_df_json_1["Field"] = "IT"
monster_ph_df_json_2 = pd.read_json(r'Monster Data/monster_ph_health-care.json')
monster_ph_df_json_2["Field"] = "Medicine"
monster_ph_df_json_3 = pd.read_json(r'Monster Data/monster_ph_manufacturing-engineering.json')
monster_ph_df_json_3["Field"] = "Engineering"
monster_ph_df_json_4 = pd.read_json(r'Monster Data/monster_ph_pharmaceutical-biotechnology.json')
monster_ph_df_json_4["Field"] = "Medicine"
monster_ph_df_json_5 = pd.read_json(r'Monster Data/monster_ph_telecom-isp.json')
monster_ph_df_json_5["Field"] = "IT"
monster_ph_df_json_6 = pd.read_json(r'Monster Data/monster_ph_engineering-mechanical-automotive-industrial-jobs.json')
monster_ph_df_json_6["Field"] = "Engineering"

# %%
monster_ph_df_json_1 = monster_ph_df_json_1.rename(columns = {'Years of Work Expirience': 'Years of Work Experience'}, inplace = False)
monster_ph_df_json_2 = monster_ph_df_json_2.rename(columns = {'Years of Work Expirience': 'Years of Work Experience'}, inplace = False)
monster_ph_df_json_3 = monster_ph_df_json_3.rename(columns = {'Years of Work Expirience': 'Years of Work Experience'}, inplace = False)
monster_ph_df_json_4 = monster_ph_df_json_4.rename(columns = {'Years of Work Expirience': 'Years of Work Experience'}, inplace = False)
monster_ph_df_json_5 = monster_ph_df_json_5.rename(columns = {'Years of Work Expirience': 'Years of Work Experience'}, inplace = False)
monster_ph_df_json_6 = monster_ph_df_json_6.rename(columns = {'Years of Work Expirience': 'Years of Work Experience'}, inplace = False)

# %%
data = monster_ph_df_json_6.to_json(orient='records')
parsed = json.loads(data)
json.dumps(parsed, indent=4) 
with open('Monster Data/monster_ph_engineering-mechanical-automotive-industrial-jobs.json', 'w') as json_file:
    json.dump(parsed, json_file)

# %%
#pinoyjobs_df
#pinoyjobs_df_json_clean
#workbank
#workbank_df_json_clean
#compiled_df

# %%
data = pinoy_jobs.to_json(orient='records')
parsed = json.loads(data)
json.dumps(parsed, indent=4) 
with open('pinoy_jobs.json', 'w') as json_file:
    json.dump(parsed, json_file)

# %%
data = pinoyjobs_df_json_clean.to_json(orient='records')
parsed = json.loads(data)
json.dumps(parsed, indent=4) 
with open('pinoyjobs_df_json_clean.json', 'w') as json_file:
    json.dump(parsed, json_file)

# %%
data = workbank.to_json(orient='records')
parsed = json.loads(data)
json.dumps(parsed, indent=4) 
with open('workbank.json', 'w') as json_file:
    json.dump(parsed, json_file)

# %%
data = workbank_df_json_clean.to_json(orient='records')
parsed = json.loads(data)
json.dumps(parsed, indent=4) 
with open('workbank_df_json_clean.json', 'w') as json_file:
    json.dump(parsed, json_file)

# %%
data = compiled_df.to_json(orient='records')
parsed = json.loads(data)
json.dumps(parsed, indent=4) 
with open('compiled_df.json', 'w') as json_file:
    json.dump(parsed, json_file)

# %%
JOBLUM_GEO_DF = JOBLUM_GEO_DF.rename(columns = {'Years of Work Expirience': 'Years of Work Experience','Min Years of Work Expirience': 'Min Years of Work Experience','Max Years of Work Expirience': 'Max Years of Work Experience'}, inplace = False)

# %%
JOBLUM_AGRI_DF.to_csv ('Joblum Data\JOBLUM-AGRI.csv', index = False)
JOBLUM_ARCHI_DF.to_csv ('Joblum Data\JOBLUM-ARCHI.csv', index = False)
JOBLUM_AVI_DF.to_csv ('Joblum Data\JOBLUM-AVI.csv', index = False)
JOBLUM_BIOMED_DF.to_csv ('Joblum Data\JOBLUM-BIOMED.csv', index = False)
JOBLUM_BIOTECH_DF.to_csv ('Joblum Data\JOBLUM-BIOTECH.csv', index = False)
JOBLUM_CHEM_DF.to_csv ('Joblum Data\JOBLUM-CHEM.csv', index = False)
JOBLUM_CHEMENG_DF.to_csv ('Joblum Data\JOBLUM-CHEMENG.csv', index = False)
JOBLUM_CIVILENG_DF.to_csv ('Joblum Data\JOBLUM-CIVILENG.csv', index = False)
JOBLUM_CONSTRUCTION_DF.to_csv ('Joblum Data\JOBLUM-CONSTRUCTION.csv', index = False)
JOBLUM_DOCTOR_DF.to_csv ('Joblum Data\JOBLUM-DOCTOR.csv', index = False)
JOBLUM_ELECENG_DF.to_csv ('Joblum Data\JOBLUM-ELECENG.csv', index = False)
JOBLUM_ELECTRO_DF.to_csv ('Joblum Data\JOBLUM-ELECTRO.csv', index = False)
JOBLUM_ELECTROENG_DF.to_csv ('Joblum Data\JOBLUM-ELECTROENG.csv', index = False)
JOBLUM_ENG_DF.to_csv ('Joblum Data\JOBLUM-ENG.csv', index = False)
JOBLUM_ENVI_DF.to_csv ('Joblum Data\JOBLUM-ENVI.csv', index = False)
JOBLUM_ENVIENG_DF.to_csv ('Joblum Data\JOBLUM-ENVIENG.csv', index = False)
JOBLUM_GEO_DF.to_csv ('Joblum Data\JOBLUM-GEO.csv', index = False)
JOBLUM_INDUSENG_DF.to_csv ('Joblum Data\JOBLUM-INDUSENG.csv', index = False)
JOBLUM_IT_HARDWARE_DF.to_csv ('Joblum Data\JOBLUM-IT_HARDWARE.csv', index = False)
JOBLUM_IT_SOFTWARE_DF.to_csv ('Joblum Data\JOBLUM-IT_SOFTWARE.csv', index = False)
JOBLUM_IT_SYS_DF.to_csv ('Joblum Data\JOBLUM-IT_SYS.csv', index = False)
JOBLUM_MAINTENANCE_DF.to_csv ('Joblum Data\JOBLUM-MAINTENANCE.csv', index = False)
JOBLUM_MECH_DF.to_csv ('Joblum Data\JOBLUM-MECH.csv', index = False)
JOBLUM_MECHENG_DF.to_csv ('Joblum Data\JOBLUM-MECHENG.csv', index = False)
JOBLUM_NURSE_DF.to_csv ('Joblum Data\JOBLUM-NURSE.csv', index = False)
JOBLUM_NUTRI_DF.to_csv ('Joblum Data\JOBLUM-NUTRI.csv', index = False)
JOBLUM_OIL_DF.to_csv ('Joblum Data\JOBLUM-OIL.csv', index = False)
JOBLUM_OILENG_DF.to_csv ('Joblum Data\JOBLUM-OILENG.csv', index = False)
JOBLUM_PHARMA_DF.to_csv ('Joblum Data\JOBLUM-PHARMA.csv', index = False)
JOBLUM_QUALITY_DF.to_csv ('Joblum Data\JOBLUM-QUALITY.csv', index = False)
JOBLUM_QUANTITY_DF.to_csv ('Joblum Data\JOBLUM-QUANTITY.csv', index = False)
JOBLUM_SNT_DF.to_csv ('Joblum Data\JOBLUM-SNT.csv', index = False)
JOBLUM_STAT_DF.to_csv ('Joblum Data\JOBLUM-STAT.csv', index = False)

# %%
JOBLUM_ENVIENG_DF
# Out:
#   Website                      Job Title                   Category  \
# 0  Joblum  Senior Ruby on Rails Engineer  Environmental Engineering
#
#                      Company Date Posted                   Location  \
# 0  Axis Online Ventures Inc.  2021-05-26  Mandaluyong – WFH for now
#
#           Status         Salary                       Education  \
# 0  Not Specified  74,000-75,000  Not Specified / In Description
#
#          Years of Work Experience  \
# 0  Not Specified / In Description
#
#                                      Job Description Min Salary Max Salary  \
# 0  Senior Ruby on Rails Engineer Product, Enginee...     74,000     75,000
#
#   Min Years of Work Experience Max Years of Work Experience        Field
# 0                Not Specified                Not Specified  Engineering

# %%
#Combine all CSV created 
JOBLUM_AGRI_DF = pd.read_csv('Joblum Data\JOBLUM-AGRI.csv')
JOBLUM_ARCHI_DF = pd.read_csv('Joblum Data\JOBLUM-ARCHI.csv')
JOBLUM_AVI_DF = pd.read_csv('Joblum Data\JOBLUM-AVI.csv')
JOBLUM_BIOMED_DF = pd.read_csv('Joblum Data\JOBLUM-BIOMED.csv')
JOBLUM_BIOTECH_DF = pd.read_csv('Joblum Data\JOBLUM-BIOTECH.csv') 
JOBLUM_CHEM_DF = pd.read_csv('Joblum Data\JOBLUM-CHEM.csv')
JOBLUM_CHEMENG_DF = pd.read_csv('Joblum Data\JOBLUM-CHEMENG.csv')
JOBLUM_CIVILENG_DF = pd.read_csv('Joblum Data\JOBLUM-CIVILENG.csv')
JOBLUM_CONSTRUCTION_DF = pd.read_csv('Joblum Data\JOBLUM-CONSTRUCTION.csv')
JOBLUM_DOCTOR_DF = pd.read_csv('Joblum Data\JOBLUM-DOCTOR.csv')
JOBLUM_ELECENG_DF = pd.read_csv('Joblum Data\JOBLUM-ELECENG.csv')
JOBLUM_ELECTRO_DF = pd.read_csv('Joblum Data\JOBLUM-ELECTRO.csv')
JOBLUM_ELECTROENG_DF = pd.read_csv('Joblum Data\JOBLUM-ELECTROENG.csv')
JOBLUM_ENG_DF = pd.read_csv('Joblum Data\JOBLUM-ENG.csv')
JOBLUM_ENVI_DF = pd.read_csv('Joblum Data\JOBLUM-ENVI.csv')
JOBLUM_ENVIENG_DF = pd.read_csv('Joblum Data\JOBLUM-ENVIENG.csv')
JOBLUM_GEO_DF = pd.read_csv('Joblum Data\JOBLUM-GEO.csv')
JOBLUM_INDUSENG_DF = pd.read_csv('Joblum Data\JOBLUM-INDUSENG.csv')
JOBLUM_IT_HARDWARE_DF = pd.read_csv('Joblum Data\JOBLUM-IT_HARDWARE.csv')
JOBLUM_IT_SOFTWARE_DF = pd.read_csv('Joblum Data\JOBLUM-IT_SOFTWARE.csv')
JOBLUM_IT_SYS_DF = pd.read_csv('Joblum Data\JOBLUM-IT_SYS.csv')
JOBLUM_MAINTENANCE_DF = pd.read_csv('Joblum Data\JOBLUM-MAINTENANCE.csv')
JOBLUM_MECH_DF = pd.read_csv('Joblum Data\JOBLUM-MECH.csv')
JOBLUM_MECHENG_DF = pd.read_csv('Joblum Data\JOBLUM-MECHENG.csv')
JOBLUM_NURSE_DF = pd.read_csv('Joblum Data\JOBLUM-NURSE.csv')
JOBLUM_NUTRI_DF = pd.read_csv('Joblum Data\JOBLUM-NUTRI.csv')
JOBLUM_OIL_DF = pd.read_csv('Joblum Data\JOBLUM-OIL.csv')
JOBLUM_OILENG_DF = pd.read_csv('Joblum Data\JOBLUM-OILENG.csv')
JOBLUM_PHARMA_DF = pd.read_csv('Joblum Data\JOBLUM-PHARMA.csv')
JOBLUM_QUALITY_DF = pd.read_csv('Joblum Data\JOBLUM-QUALITY.csv')
JOBLUM_QUANTITY_DF = pd.read_csv('Joblum Data\JOBLUM-QUANTITY.csv')
JOBLUM_SNT_DF = pd.read_csv('Joblum Data\JOBLUM-SNT.csv')
JOBLUM_STAT_DF = pd.read_csv('Joblum Data\JOBLUM-STAT.csv')

JOBLUM_df = pd.concat([JOBLUM_AGRI_DF, JOBLUM_ARCHI_DF, JOBLUM_AVI_DF,
                      JOBLUM_AVI_DF, JOBLUM_BIOTECH_DF, JOBLUM_CHEM_DF,
                      JOBLUM_CHEMENG_DF, JOBLUM_CIVILENG_DF, JOBLUM_CONSTRUCTION_DF,
                      JOBLUM_DOCTOR_DF, JOBLUM_ELECENG_DF, JOBLUM_ELECTRO_DF,
                      JOBLUM_ELECTROENG_DF, JOBLUM_ENG_DF, JOBLUM_ENVI_DF,
                      JOBLUM_ENVIENG_DF, JOBLUM_GEO_DF, JOBLUM_INDUSENG_DF,
                      JOBLUM_IT_HARDWARE_DF, JOBLUM_IT_SOFTWARE_DF, JOBLUM_IT_SYS_DF,
                      JOBLUM_MAINTENANCE_DF, JOBLUM_MECH_DF, JOBLUM_MECHENG_DF,
                      JOBLUM_NURSE_DF, JOBLUM_NUTRI_DF, JOBLUM_OIL_DF,
                      JOBLUM_OILENG_DF, JOBLUM_PHARMA_DF, JOBLUM_QUALITY_DF,
                      JOBLUM_QUANTITY_DF, JOBLUM_SNT_DF, JOBLUM_STAT_DF],ignore_index=True, sort=False)
JOBLUM_df
# Out:
#       Website                                          Job Title  \
# 0      Joblum          Technical Sales Representative (Mindanao)
# 1      Joblum                                     Farm Worker II
# 2      Joblum                          AGRICULTURAL TECHNOLOGIST
# 3      Joblum                                    Farm Worker - I
# 4      Joblum                               Senior Aquaculturist
# ...       ...                                                ...
# 16248  Joblum                       Statistician Aide (010-0465)
# 16249  Joblum                              ELECTION ASSISTANT II
# 16250  Joblum                               ELECTION ASSISTANT I
# 16251  Joblum                                  Reporting Analyst
# 16252  Joblum  NIGHT SHIFT & TEMPORARY WFH | Data Scientist (...
#
#                    Category                                          Company  \
# 0               Agriculture         La Filipina Uy Gongco Group of Companies
# ...
